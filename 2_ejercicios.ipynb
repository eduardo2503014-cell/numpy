# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape


print("Dimensiones de la imagen:", img.shape)
print("Color del píxel [0,10]:", img[0, 10])
# Out:
# Dimensiones de la imagen: (1024, 1024, 3)
# Color del píxel [0,10]: [25 38  8]
